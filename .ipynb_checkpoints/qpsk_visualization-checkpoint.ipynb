# %%
# !pip install PyQt5
# !pwd
# Out:
# Requirement already satisfied: PyQt5 in /home/incredible/Projects/python/dsp_dev_env/lib/python3.12/site-packages (5.15.11)
# Requirement already satisfied: PyQt5-sip<13,>=12.15 in /home/incredible/Projects/python/dsp_dev_env/lib/python3.12/site-packages (from PyQt5) (12.15.0)
# Requirement already satisfied: PyQt5-Qt5<5.16.0,>=5.15.2 in /home/incredible/Projects/python/dsp_dev_env/lib/python3.12/site-packages (from PyQt5) (5.15.15)
# /home/incredible/Projects/python/signal_processing

# %%
from PyQt5.QtWidgets import *
from PyQt5.QtGui import *
from PyQt5.QtCore import Qt

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import cmath
import math
from commpy.filters import rcosfilter
from ipywidgets import interact, widgets
import dsp_lib

# %%
from scipy.signal import butter, filtfilt
import os
from array import array

# %%
# %load_ext autoreload
# %autoreload 2
import dsp_lib

# 1: Source signal
plt.close('all')
file_path = "/home/xy/cuda_filt_sig_int16.pcm"
file_path = "qpsk_rc_int16_1_sig.bin"
file_path = "/home/incredible/Projects/gpu/GPU_Overlap-and-save_convolution/GPU_OLS_C2C_sharedmemory/conv_signal.dat"
file_path = "qpsk_rrc_after_py_rrc_fl64.bin"

data_type = 'float64'
figure_counter = 0
source_samples = dsp_lib.read_signal(file_path, data_type, 0, 0, '')
source_signal = dsp_lib.make_cmplx_sig(source_samples)
print(source_signal[1031990:1031999])
dsp_lib.plot_spectrum(source_signal, 0)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [[43303.06478697]
#  [51747.25356765]
#  [59003.30129113]
#  [64554.8413312 ]
#  [68209.76950356]
#  [69907.26111333]
#  [69755.73180095]
#  [68207.70760575]
#  [65747.47414961]
#  [62750.43111299]]
# [-70636.31684162+38290.02694208j -66494.080695  +51025.60234207j
#  -60864.47684462+59542.47731323j -53944.84428538+63393.44456114j
#  -46121.15214789+62746.29034193j -37972.44492852+58076.56915904j
#  -29917.60036842+50069.50475023j -22179.54451027+39839.24197774j
#  -15105.91427112+28772.09101644j]
# array([[-30.55141221],
#        [-30.45663538],
#        [-30.41442251],
#        ...,
#        [-30.49077348],
#        [-30.43032708],
#        [-30.40514285]])

# %%
def calc_var(signal):
    m = np.mean(signal)
    var = (np.square(np.abs(signal - m)))
    print(f"mean = {m}")
    print(var[:10])
    return np.sum((np.square(np.abs(signal - m))))

def calc_signal_rms(signal):
    quar1 = [num for num in signal if (num.real > 0) & (num.imag > 0)]
    quar2 = [num for num in signal if (num.real > 0) & (num.imag < 0)]
    quar3 = [num for num in signal if (num.real < 0) & (num.imag > 0)]
    quar4 = [num for num in signal if (num.real < 0) & (num.imag < 0)]
    
    print(quar1[:10])
    var1 = calc_var(quar1)
    var2 = calc_var(quar2)
    var3 = calc_var(quar3)
    var4 = calc_var(quar4)
    rms = np.sqrt((var1 + var2 + var3 + var4) / (len(quar1) + len(quar2) + len(quar3) + len(quar4)))
    print(f"rms = {rms}")
# Out:
# [2, 4, 6, 8, 10]

# %%
def plot_iq_pcm( delay: float, fsymb_to_fsampl: float, phase: float, f0: float):
    print(f"fract omega = {f0}, fsymb_to_fsampl = {fsymb_to_fsampl}, phase = {phase}")
    matplotlib.pyplot.close()
    signal_iq = source_signal[64:(1032192 -1000)]
    mixed_sig = dsp_lib.add_freq(signal_iq, f0)
    sig_default = dsp_lib.add_phase(mixed_sig, phase)
    x0 = delay
    res_sig = dsp_lib.resampling_lagrange_step_ver(sig_default, fsymb_to_fsampl, x0)
    calc_signal_rms(res_sig)
    plt.close()
    fig = plt.figure()
    ax = fig.add_subplot()
    #print(res_sig)
    plt.plot(res_sig.real, res_sig.imag, '.')
    plt.grid()
    ax.set_aspect('equal', adjustable='box')
    plt.show()

delay_float = widgets.BoundedFloatText(
    value=0,
    min=-1,
    max=1,
    step=0.001,
    description='Delay before first symbol, samples:',
    disabled=False
)

sps = widgets.BoundedFloatText(
    value=1.0,
    min=1,
    max=50,
    step=0.00001,
    description='SPS',
    disabled=False
)

phase_float = widgets.BoundedFloatText(
    value=.0,
    min=-1,
    max=1,
    step=0.0001,
    description='Phase, [-1, 1], semicircles',
    disabled=False
)

f0_float = widgets.BoundedFloatText(
    value=.0,
    min = -1,
    max = 1,
    step = 0.00001,
    description = 'f0, [0, 1], circles',
    disabled = False
)


interact(plot_iq_pcm, delay=delay_float, fsymb_to_fsampl=sps, phase = phase_float, f0 = f0_float)
# Out:
# interactive(children=(BoundedFloatText(value=0.0, description='Delay before first symbol, samples:', max=1.0, …
# <function __main__.plot_iq_pcm(delay: float, fsymb_to_fsampl: float, phase: float, f0: float)>

# %%
224.67918395996094 # gpu fl32  225.2149200439453   223.12039184570312  225.49227905273438  225.05104064941406  225.05104064941406  227.8776092529297
225.39353942871094 # py  fl32  225.21466064453125  223.12010192871094  225.49209594726562  225.05079650878906  226.0729522705078   227.87744140625
225.39353942871094 # py  fl64  225.21463012695312  223.12010192871094  225.4921112060547   225.05079650878906  226.07296752929688  227.87744140625
# Out:
# 225.39353942871094

# %%
10 * math.log10(np.square(227.87744140625) / np.square(227.8776092529297))
# Out:
# -6.397724978804515e-06

# %%
(1.1286232574447851e-05 + -6.465402206480388e-06 + -9.422661050582148e-06 + 1.118126906836094e-05) / 4
# Out:
# 1.6448595964365638e-06

# %%
file_path = "qpsk_rrc_after_py_rrc_fl32.bin"

data_type = 'float32'
figure_counter = 0
source_samples_py = read_float_by_unpack_delimeter(file_path, data_type, 0, 0, '')
source_signal_py = make_cmplx_sig(source_samples_py)
plot_spectrum(source_signal_py, 7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 5
#       3 data_type = 'float32'
#       4 figure_counter = 0
# ----> 5 source_samples_py = read_float_by_unpack_delimeter(file_path, data_type, 0, 0, '')
#       6 source_signal_py = make_cmplx_sig(source_samples_py)
#       7 plot_spectrum(source_signal_py, 7)
#
# NameError: name 'read_float_by_unpack_delimeter' is not defined

# %%
diff = (source_signal_py - source_signal[:len(source_signal_py)])
#plot_signal_power(diff, 6)

print(source_signal[:10])
print(source_signal_py[:10])

# %%
10 * math.log10(np.square(224.977) / np.square(224.08684))

# %%
10 * math.log10(np.square(223.12039184570312) / np.square(223.12010192871094)) # 224.0868377685547
