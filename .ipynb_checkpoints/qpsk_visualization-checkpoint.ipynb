# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import cmath
import math
from commpy.filters import rcosfilter
from ipywidgets import interact, widgets

# %%
def resampling_lagrange(s, p, q, x0):
    """
    % y = resample_lagrange(s, p, q, x0)
    % Digital resampling by polynomial Lagrange interpolation.
    % Function changes input signal s samplerate to p/q times and adds fractional
    % delay.
    %
    % Input parameters
    %  s   - input signal vector [N x 1];
    %  p   - p paramter of samplarate conversion
    %  q   - q paramter of samplarate conversion
    %  x0  - fractional delay
    %
    % Ouptut parameters
    %  y   - Resampled signal
    %
    % Author: Sergey Bakhurin (dsplib.org)
    """
    if (p > 1):
        if (q == 1):
            y = np.zeros(int(float((len(s) - 1) * p) / float(q)) + 1)
        else:
            y = np.zeros(int(float(len(s) * p) / float(q)))
    else:
        y = np.zeros(int(float(len(s) * p) / float(q)))

    t = np.zeros(len(y))
    s = np.concatenate((np.array([0., 0.]), s, np.array([0., 0.])))

    for k in range(len(y)):
        x = k * q / p - x0
        t[k] = x
        n = int(np.floor(x)) + 4
        d = np.floor(x) + 1 - x
        a0 = s[n - 1]
        a3 = 1 / 6 * (s[n] - s[n - 3]) + 0.5 * (s[n - 2] - s[n - 1])
        a1 = 0.5 * (s[n] - s[n - 2]) - a3
        a2 = s[n] - s[n - 1] - a3 - a1

        y[k] = a0 - a1 * d + a2 * d ** 2 - a3 * d ** 3

    return y

# %%
def calculate_spectrum(signal):
    yf = np.fft.fft(signal)
    yf = np.abs(yf.reshape((len(yf), 1))) / len(signal)
    return yf


def plot_spectrum(signal, figure_counter, title="Amplitude spectrum"):
    spectrum = np.roll(calculate_spectrum(signal), len(signal) // 2)
    yf = 20 * np.log10(spectrum)
    plt.figure(figure_counter)
    x_data = np.arange(-len(spectrum) // 2 + 1, len(spectrum) // 2 + 1)
    x_data = x_data / (len(spectrum) / 2)
    plt.plot(x_data, yf)
    plt.grid(1)
    plt.xlabel('Frequency (semicircles)')
    plt.ylabel('Magnitude (dB)')
    plt.title(title)
    return yf

# %%
def gen_rcfilter_impulse_response(n, fs):
    s_psf = rcosfilter(n * fs, alpha=0.24, Ts=1, Fs=fs)[1][1:]
    plt.figure()
    plt.plot(s_psf, '*-')
    plt.grid()
    plt.title('RC filter impulse response')
    return s_psf

# %%
def gen_qpsk_symbols(n_symb, fs):
    # create IQ of QPSK
    data = np.random.randint(0, 4, n_symb)
    #x_tr = x.transpose()
    y = [-1 - 1j, -1 + 1j, 1 - 1j, 1 + 1j]
    iq = [y[val] for val in data]
    iq_ups = np.zeros(N * fs, dtype=complex)
    iq_ups[:len(iq) * fs:fs] = iq
    return iq_ups

# %%
N = 100
Fs = 4
s_rc = gen_rcfilter_impulse_response(N, Fs)
s_qpsk = gen_qpsk_symbols(N, Fs)
s_rc_re = np.convolve(s_qpsk.real, s_rc, 'same')
s_rc_im = np.convolve(s_qpsk.imag, s_rc, 'same')
plt.figure()
plt.stem(s_qpsk.real, '*-')
plt.plot(s_rc_re, '*-')
plt.grid()
plt.show()

plt.figure()
plt.stem(s_qpsk.imag, '*-')
plt.plot(s_rc_im, '*-')
plt.grid()
plt.show()

# %%
p = 1
q = 1
x0 = 0.1 # it is negative delay
global s_rc_re_delay 
s_rc_re_delay = resampling_lagrange(s_rc_re, p, q, x0)
global s_rc_im_delay 
s_rc_im_delay = resampling_lagrange(s_rc_im, p, q, x0)
# %matplotlib widget

plt.figure()
plt.plot(s_rc_re, 'b*-')
plt.plot(s_rc_re_delay, 'r*-')
plt.grid()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
p = 1
q = 1
x0 = -0.1 # it is negative delay
s_rc_re_down = resampling_lagrange(s_rc_re_delay, p, q, x0)
s_rc_im_down = resampling_lagrange(s_rc_im_delay, p, q, x0)

p = 1
q = 4
x0 = 0
s_rc_re_down = resampling_lagrange(s_rc_re_down, p, q, x0)
s_rc_im_down = resampling_lagrange(s_rc_im_down, p, q, x0)

plt.figure()
plt.plot(s_rc_re_down, s_rc_im_down, '.')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def plot_iq(delay, omega_semicircl):
    p = 1
    q = 1
    x0 = delay # it is negative delay
    s_rc_re_down = resampling_lagrange(s_rc_re_delay, p, q, x0)
    s_rc_im_down = resampling_lagrange(s_rc_im_delay, p, q, x0)
    
    p = 1
    q = 4
    x0 = 0
    s_rc_re_down = resampling_lagrange(s_rc_re_down, p, q, x0)
    s_rc_im_down = resampling_lagrange(s_rc_im_down, p, q, x0)
    s_rc_down = s_rc_re_down + 1j * s_rc_im_down

    n = np.arange(0, len(s_rc_down), 1)
    mixer = np.exp(1j * np.pi * omega_semicircl * n)
    res_sig = s_rc_down * mixer

    
    plt.figure()
    plt.plot(res_sig.real, res_sig.imag, '.')
    plt.show()

# %%
delay_slider = widgets.FloatSlider(value=1.0, min=-1, max=1, step=0.1, description='Delay')
omega_slider = widgets.FloatSlider(value=1.0, min=-1, max=1, step=0.01, description='Omega')

# Use the interact function to connect the slider to the plot function
interact(plot_iq, delay=delay_slider, omega_semicircl=omega_slider)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='Delay', max=1.0, min=-1.0), FloatSlider(value=1.0, d…
# <function __main__.plot_iq(delay, omega_semicircl)>
